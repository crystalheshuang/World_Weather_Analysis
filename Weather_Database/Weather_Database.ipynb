# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Import the dependencies.
import pandas as pd
from citipy import citipy

# %%
# Get the nearest city using the citipy module.

cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
    try:
    # If the city is unique, then we will add it to the cities list.
        if city not in cities:
            cities.append(city)
    except():
        print("General Error... skipping.")   
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=63b43aa8d89c9f0dafeecbb8d2bb4238

# %%
# Perform an API call with the OpenWeatherMap.

# Retrieve the following information from the API call:

## Latitude and longitude
## Maximum temperature
## Percent humidity
## Percent cloudiness
## Wind speed
## Weather description (for example, clouds, fog, light rain, clear sky)


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # city_weather_main=city_weather["weather"][0]["main"]   
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          # "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | fortuna
# Processing Record 4 of Set 1 | yabrud
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | faanui
# Processing Record 13 of Set 1 | balaipungut
# Processing Record 14 of Set 1 | norman wells
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | dromolaxia
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | lorengau
# Processing Record 19 of Set 1 | maceio
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | necochea
# Processing Record 22 of Set 1 | sapa
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | comodoro rivadavia
# Processing Record 25 of Set 1 | lompoc
# Processing Record 26 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | yeniseysk
# Processing Record 32 of Set 1 | tukrah
# Processing Record 33 of Set 1 | kelowna
# Processing Record 34 of Set 1 | felanitx
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | cockburn town
# Processing Record 37 of Set 1 | nome
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | nanortalik
# Processing Record 41 of Set 1 | pacocha
# Processing Record 42 of Set 1 | pochutla
# Processing Record 43 of Set 1 | ulladulla
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | narsaq
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | yendi
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | kieta
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | geraldton
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | te anau
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | balsas
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | srednekolymsk
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | hermanus
# Processing Record 29 of Set 2 | san ramon
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | port hedland
# Processing Record 32 of Set 2 | umea
# Processing Record 33 of Set 2 | piacabucu
# Processing Record 34 of Set 2 | labuhan
# Processing Record 35 of Set 2 | tahoua
# Processing Record 36 of Set 2 | nueva germania
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | clarksburg
# Processing Record 39 of Set 2 | mahebourg
# Processing Record 40 of Set 2 | chipinge
# Processing Record 41 of Set 2 | kirksville
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | carauari
# Processing Record 44 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | half moon bay
# Processing Record 48 of Set 2 | mahmudia
# Processing Record 49 of Set 2 | granville
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | kununurra
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 4 of Set 3 | vysokogornyy
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | talnakh
# Processing Record 7 of Set 3 | semnan
# Processing Record 8 of Set 3 | newport
# Processing Record 9 of Set 3 | constitucion
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | duz
# City not found. Skipping...
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | bardiyah
# Processing Record 15 of Set 3 | springbok
# Processing Record 16 of Set 3 | kruisfontein
# Processing Record 17 of Set 3 | vila velha
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | santa rosa
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | tongzi
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | lebu
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | yerofey pavlovich
# Processing Record 27 of Set 3 | nacala
# Processing Record 28 of Set 3 | saint george
# Processing Record 29 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 3 | diego de almagro
# Processing Record 31 of Set 3 | yekaterinogradskaya
# Processing Record 32 of Set 3 | rio gallegos
# Processing Record 33 of Set 3 | skjervoy
# Processing Record 34 of Set 3 | avera
# Processing Record 35 of Set 3 | gravelbourg
# Processing Record 36 of Set 3 | gazalkent
# Processing Record 37 of Set 3 | santa helena
# Processing Record 38 of Set 3 | bengkulu
# Processing Record 39 of Set 3 | buraydah
# Processing Record 40 of Set 3 | port-cartier
# Processing Record 41 of Set 3 | ode
# Processing Record 42 of Set 3 | matara
# Processing Record 43 of Set 3 | tutoia
# Processing Record 44 of Set 3 | stokmarknes
# Processing Record 45 of Set 3 | farafangana
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | nenjiang
# Processing Record 48 of Set 3 | howard springs
# Processing Record 49 of Set 3 | thunder bay
# Processing Record 50 of Set 3 | hofn
# Processing Record 1 of Set 4 | praia da vitoria
# Processing Record 2 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | moose factory
# Processing Record 5 of Set 4 | ewa beach
# Processing Record 6 of Set 4 | jahrom
# City not found. Skipping...
# Processing Record 7 of Set 4 | atuona
# Processing Record 8 of Set 4 | burgthann
# Processing Record 9 of Set 4 | seka
# Processing Record 10 of Set 4 | touros
# Processing Record 11 of Set 4 | po
# City not found. Skipping...
# Processing Record 12 of Set 4 | san quintin
# Processing Record 13 of Set 4 | souillac
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | barrow
# Processing Record 16 of Set 4 | port lincoln
# Processing Record 17 of Set 4 | ballina
# Processing Record 18 of Set 4 | pemba
# Processing Record 19 of Set 4 | burnie
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | esperance
# Processing Record 23 of Set 4 | nemuro
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 26 of Set 4 | waipawa
# Processing Record 27 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | juybar
# Processing Record 30 of Set 4 | namibe
# Processing Record 31 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 4 | moron
# Processing Record 34 of Set 4 | sayat
# Processing Record 35 of Set 4 | birao
# Processing Record 36 of Set 4 | grand gaube
# Processing Record 37 of Set 4 | pervomayskiy
# Processing Record 38 of Set 4 | martapura
# Processing Record 39 of Set 4 | saiha
# Processing Record 40 of Set 4 | mitsamiouli
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 4 | olinda
# Processing Record 44 of Set 4 | kochevo
# Processing Record 45 of Set 4 | sao joao da barra
# Processing Record 46 of Set 4 | vostok
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | luganville
# Processing Record 49 of Set 4 | behshahr
# Processing Record 50 of Set 4 | grindavik
# Processing Record 1 of Set 5 | spring hill
# Processing Record 2 of Set 5 | lodwar
# Processing Record 3 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | meulaboh
# Processing Record 6 of Set 5 | christchurch
# Processing Record 7 of Set 5 | victoria
# Processing Record 8 of Set 5 | greytown
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | muros
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | portland
# Processing Record 13 of Set 5 | lewisporte
# Processing Record 14 of Set 5 | miramar
# Processing Record 15 of Set 5 | pozo colorado
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | ketchikan
# Processing Record 18 of Set 5 | lata
# Processing Record 19 of Set 5 | yerbogachen
# Processing Record 20 of Set 5 | bilma
# Processing Record 21 of Set 5 | isangel
# Processing Record 22 of Set 5 | taicheng
# Processing Record 23 of Set 5 | ahipara
# Processing Record 24 of Set 5 | conceicao do almeida
# Processing Record 25 of Set 5 | lima
# Processing Record 26 of Set 5 | santa marta
# Processing Record 27 of Set 5 | ryabovo
# Processing Record 28 of Set 5 | fomboni
# Processing Record 29 of Set 5 | namtsy
# Processing Record 30 of Set 5 | jieznas
# Processing Record 31 of Set 5 | acarau
# Processing Record 32 of Set 5 | mongoumba
# Processing Record 33 of Set 5 | khatanga
# Processing Record 34 of Set 5 | mar del plata
# Processing Record 35 of Set 5 | marawi
# Processing Record 36 of Set 5 | guangyuan
# Processing Record 37 of Set 5 | north bend
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | shache
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | olga
# Processing Record 42 of Set 5 | colares
# Processing Record 43 of Set 5 | dickinson
# Processing Record 44 of Set 5 | itoman
# Processing Record 45 of Set 5 | sao filipe
# Processing Record 46 of Set 5 | tambura
# Processing Record 47 of Set 5 | manono
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | urubicha
# Processing Record 50 of Set 5 | flin flon
# Processing Record 1 of Set 6 | rosario
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | barcelos
# Processing Record 4 of Set 6 | anastacio
# Processing Record 5 of Set 6 | saint-louis
# Processing Record 6 of Set 6 | tiksi
# Processing Record 7 of Set 6 | yar-sale
# Processing Record 8 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 6 | tanout
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | billings
# Processing Record 12 of Set 6 | kloulklubed
# Processing Record 13 of Set 6 | nizhnyaya omka
# Processing Record 14 of Set 6 | shiraz
# Processing Record 15 of Set 6 | coihaique
# Processing Record 16 of Set 6 | tautira
# Processing Record 17 of Set 6 | yepifan
# Processing Record 18 of Set 6 | male
# Processing Record 19 of Set 6 | severo-kurilsk
# Processing Record 20 of Set 6 | hoi an
# Processing Record 21 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 6 | ferme-neuve
# Processing Record 23 of Set 6 | nyurba
# Processing Record 24 of Set 6 | broken hill
# Processing Record 25 of Set 6 | ponta do sol
# Processing Record 26 of Set 6 | vestmannaeyjar
# Processing Record 27 of Set 6 | ilulissat
# Processing Record 28 of Set 6 | garavuti
# Processing Record 29 of Set 6 | zmeinogorsk
# Processing Record 30 of Set 6 | filadelfia
# Processing Record 31 of Set 6 | ciudad bolivar
# Processing Record 32 of Set 6 | bairiki
# Processing Record 33 of Set 6 | kupang
# Processing Record 34 of Set 6 | taksimo
# Processing Record 35 of Set 6 | chake chake
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | wajir
# Processing Record 38 of Set 6 | mehamn
# Processing Record 39 of Set 6 | pangody
# Processing Record 40 of Set 6 | pitkyaranta
# Processing Record 41 of Set 6 | quatre cocos
# Processing Record 42 of Set 6 | tampa
# Processing Record 43 of Set 6 | suoyarvi
# Processing Record 44 of Set 6 | san carlos de bariloche
# Processing Record 45 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 46 of Set 6 | vaitape
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | srandakan
# Processing Record 49 of Set 6 | batemans bay
# Processing Record 50 of Set 6 | butaritari
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 2 of Set 7 | brewster
# Processing Record 3 of Set 7 | angra
# City not found. Skipping...
# Processing Record 4 of Set 7 | beihai
# Processing Record 5 of Set 7 | santa luzia
# Processing Record 6 of Set 7 | fivizzano
# Processing Record 7 of Set 7 | hami
# Processing Record 8 of Set 7 | luzhou
# Processing Record 9 of Set 7 | abu kamal
# Processing Record 10 of Set 7 | san antonio
# Processing Record 11 of Set 7 | kerman
# Processing Record 12 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 13 of Set 7 | kurilsk
# Processing Record 14 of Set 7 | tomatlan
# Processing Record 15 of Set 7 | sistranda
# Processing Record 16 of Set 7 | adrar
# Processing Record 17 of Set 7 | tabora
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | neuquen
# Processing Record 20 of Set 7 | ternate
# Processing Record 21 of Set 7 | coquimbo
# Processing Record 22 of Set 7 | klaksvik
# Processing Record 23 of Set 7 | clayton
# Processing Record 24 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 7 | najran
# Processing Record 26 of Set 7 | pasni
# Processing Record 27 of Set 7 | xuddur
# Processing Record 28 of Set 7 | marsh harbour
# Processing Record 29 of Set 7 | lingao
# Processing Record 30 of Set 7 | chara
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | kayes
# Processing Record 33 of Set 7 | katsuura
# Processing Record 34 of Set 7 | wuwei
# Processing Record 35 of Set 7 | santo angelo
# Processing Record 36 of Set 7 | hovd
# Processing Record 37 of Set 7 | sitka
# Processing Record 38 of Set 7 | bogashevo
# Processing Record 39 of Set 7 | richards bay
# Processing Record 40 of Set 7 | thinadhoo
# Processing Record 41 of Set 7 | axim
# Processing Record 42 of Set 7 | hay river
# Processing Record 43 of Set 7 | raudeberg
# Processing Record 44 of Set 7 | moche
# Processing Record 45 of Set 7 | sharjah
# Processing Record 46 of Set 7 | broome
# Processing Record 47 of Set 7 | bosaso
# Processing Record 48 of Set 7 | la rioja
# Processing Record 49 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 7 | hambantota
# Processing Record 1 of Set 8 | aykhal
# Processing Record 2 of Set 8 | florianopolis
# Processing Record 3 of Set 8 | bontang
# Processing Record 4 of Set 8 | kurmanayevka
# Processing Record 5 of Set 8 | kisangani
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | fenoarivo atsinanana
# Processing Record 8 of Set 8 | tabuk
# Processing Record 9 of Set 8 | villa carlos paz
# Processing Record 10 of Set 8 | skiros
# City not found. Skipping...
# Processing Record 11 of Set 8 | tual
# Processing Record 12 of Set 8 | luderitz
# Processing Record 13 of Set 8 | salinopolis
# Processing Record 14 of Set 8 | komsomolskiy
# Processing Record 15 of Set 8 | valparaiso
# Processing Record 16 of Set 8 | lucea
# Processing Record 17 of Set 8 | guilin
# Processing Record 18 of Set 8 | rohri
# Processing Record 19 of Set 8 | luangwa
# Processing Record 20 of Set 8 | palmeiras de goias
# Processing Record 21 of Set 8 | sumter
# Processing Record 22 of Set 8 | moba
# Processing Record 23 of Set 8 | boa vista
# Processing Record 24 of Set 8 | tahe
# Processing Record 25 of Set 8 | altay
# Processing Record 26 of Set 8 | wicklow
# Processing Record 27 of Set 8 | kayasula
# Processing Record 28 of Set 8 | rio verde de mato grosso
# Processing Record 29 of Set 8 | yazd
# Processing Record 30 of Set 8 | voi
# Processing Record 31 of Set 8 | maxixe
# Processing Record 32 of Set 8 | mhlume
# Processing Record 33 of Set 8 | dong xoai
# Processing Record 34 of Set 8 | svetlogorsk
# Processing Record 35 of Set 8 | amapa
# Processing Record 36 of Set 8 | sola
# Processing Record 37 of Set 8 | narasannapeta
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | shamilkala
# Processing Record 40 of Set 8 | bubaque
# Processing Record 41 of Set 8 | chapais
# Processing Record 42 of Set 8 | ruwi
# Processing Record 43 of Set 8 | naldurg
# Processing Record 44 of Set 8 | goundam
# Processing Record 45 of Set 8 | paamiut
# Processing Record 46 of Set 8 | karratha
# Processing Record 47 of Set 8 | saint-pierre
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | kutum
# Processing Record 50 of Set 8 | rabat
# Processing Record 1 of Set 9 | arona
# Processing Record 2 of Set 9 | iranshahr
# Processing Record 3 of Set 9 | dawson creek
# Processing Record 4 of Set 9 | araouane
# Processing Record 5 of Set 9 | pangnirtung
# Processing Record 6 of Set 9 | jacareacanga
# Processing Record 7 of Set 9 | hithadhoo
# Processing Record 8 of Set 9 | college
# Processing Record 9 of Set 9 | beloha
# Processing Record 10 of Set 9 | taltal
# Processing Record 11 of Set 9 | ayan
# Processing Record 12 of Set 9 | indramayu
# Processing Record 13 of Set 9 | ankang
# Processing Record 14 of Set 9 | kaele
# Processing Record 15 of Set 9 | vila franca do campo
# Processing Record 16 of Set 9 | katherine
# Processing Record 17 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 9 | xining
# Processing Record 19 of Set 9 | mount isa
# Processing Record 20 of Set 9 | nuevitas
# Processing Record 21 of Set 9 | kachug
# Processing Record 22 of Set 9 | manado
# Processing Record 23 of Set 9 | mujiayingzi
# Processing Record 24 of Set 9 | gizo
# Processing Record 25 of Set 9 | sechura
# Processing Record 26 of Set 9 | nikolskoye
# Processing Record 27 of Set 9 | dighwara
# Processing Record 28 of Set 9 | shimoda
# Processing Record 29 of Set 9 | manacapuru
# Processing Record 30 of Set 9 | bogo
# Processing Record 31 of Set 9 | mamontovo
# Processing Record 32 of Set 9 | ust-nera
# Processing Record 33 of Set 9 | ngozi
# Processing Record 34 of Set 9 | kismayo
# Processing Record 35 of Set 9 | otradnoye
# Processing Record 36 of Set 9 | kazanskoye
# Processing Record 37 of Set 9 | alekseyevka
# Processing Record 38 of Set 9 | machachi
# Processing Record 39 of Set 9 | mayor pablo lagerenza
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | vardo
# Processing Record 42 of Set 9 | baghmara
# Processing Record 43 of Set 9 | kavos
# Processing Record 44 of Set 9 | segou
# Processing Record 45 of Set 9 | opportunity
# Processing Record 46 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 9 | dhidhdhoo
# Processing Record 48 of Set 9 | olafsvik
# Processing Record 49 of Set 9 | tighina
# Processing Record 50 of Set 9 | navolato
# Processing Record 1 of Set 10 | wajima
# Processing Record 2 of Set 10 | jhang
# Processing Record 3 of Set 10 | porto walter
# Processing Record 4 of Set 10 | great yarmouth
# Processing Record 5 of Set 10 | talara
# Processing Record 6 of Set 10 | naifaru
# Processing Record 7 of Set 10 | quelimane
# Processing Record 8 of Set 10 | kamina
# Processing Record 9 of Set 10 | pandan
# Processing Record 10 of Set 10 | brae
# Processing Record 11 of Set 10 | sorland
# Processing Record 12 of Set 10 | porto de moz
# Processing Record 13 of Set 10 | amahai
# Processing Record 14 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 10 | presidencia roque saenz pena
# Processing Record 16 of Set 10 | apaxtla
# City not found. Skipping...
# Processing Record 17 of Set 10 | alamosa
# Processing Record 18 of Set 10 | kirakira
# Processing Record 19 of Set 10 | teluk nibung
# Processing Record 20 of Set 10 | alofi
# Processing Record 21 of Set 10 | san isidro
# Processing Record 22 of Set 10 | leningradskiy
# Processing Record 23 of Set 10 | opuwo
# Processing Record 24 of Set 10 | san cristobal
# Processing Record 25 of Set 10 | balykshi
# Processing Record 26 of Set 10 | venado tuerto
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | mandal
# Processing Record 29 of Set 10 | antofagasta
# Processing Record 30 of Set 10 | bilibino
# Processing Record 31 of Set 10 | champerico
# Processing Record 32 of Set 10 | oranjemund
# Processing Record 33 of Set 10 | honningsvag
# Processing Record 34 of Set 10 | nago
# Processing Record 35 of Set 10 | siderno
# Processing Record 36 of Set 10 | mount pleasant
# Processing Record 37 of Set 10 | vitina
# Processing Record 38 of Set 10 | mandalgovi
# Processing Record 39 of Set 10 | laguna
# Processing Record 40 of Set 10 | vertientes
# Processing Record 41 of Set 10 | sankheda
# Processing Record 42 of Set 10 | okhotsk
# Processing Record 43 of Set 10 | port augusta
# Processing Record 44 of Set 10 | kampot
# Processing Record 45 of Set 10 | rincon
# Processing Record 46 of Set 10 | sunland park
# Processing Record 47 of Set 10 | mount gambier
# Processing Record 48 of Set 10 | kristiansund
# Processing Record 49 of Set 10 | haines junction
# Processing Record 50 of Set 10 | samana
# Processing Record 1 of Set 11 | hudson bay
# Processing Record 2 of Set 11 | arki
# Processing Record 3 of Set 11 | jinji
# Processing Record 4 of Set 11 | muborak
# Processing Record 5 of Set 11 | hervey bay
# Processing Record 6 of Set 11 | moerai
# Processing Record 7 of Set 11 | conde
# Processing Record 8 of Set 11 | nouadhibou
# Processing Record 9 of Set 11 | leeton
# Processing Record 10 of Set 11 | aksu
# Processing Record 11 of Set 11 | coos bay
# Processing Record 12 of Set 11 | arklow
# Processing Record 13 of Set 11 | verkhnyaya inta
# Processing Record 14 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 15 of Set 11 | yuncheng
# Processing Record 16 of Set 11 | mayo
# Processing Record 17 of Set 11 | tabou
# Processing Record 18 of Set 11 | quixada
# Processing Record 19 of Set 11 | kuruman
# Processing Record 20 of Set 11 | benghazi
# Processing Record 21 of Set 11 | zvishavane
# Processing Record 22 of Set 11 | manta
# Processing Record 23 of Set 11 | lufilufi
# Processing Record 24 of Set 11 | bolshoy uluy
# City not found. Skipping...
# Processing Record 25 of Set 11 | saint-joseph
# Processing Record 26 of Set 11 | nha trang
# Processing Record 27 of Set 11 | kilemary
# Processing Record 28 of Set 11 | mbuji-mayi
# Processing Record 29 of Set 11 | soledade
# Processing Record 30 of Set 11 | dalnerechensk
# Processing Record 31 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 11 | killybegs
# Processing Record 33 of Set 11 | el banco
# Processing Record 34 of Set 11 | burica
# City not found. Skipping...
# Processing Record 35 of Set 11 | ostrovnoy
# Processing Record 36 of Set 11 | burgos
# Processing Record 37 of Set 11 | ambulu
# Processing Record 38 of Set 11 | havre-saint-pierre
# Processing Record 39 of Set 11 | loandjili
# Processing Record 40 of Set 11 | lernakert
# Processing Record 41 of Set 11 | shingu
# Processing Record 42 of Set 11 | smithers
# Processing Record 43 of Set 11 | tonantins
# Processing Record 44 of Set 11 | nelson bay
# Processing Record 45 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 46 of Set 11 | miracema do tocantins
# Processing Record 47 of Set 11 | teguise
# Processing Record 48 of Set 11 | gushikawa
# Processing Record 49 of Set 11 | glasgow
# Processing Record 50 of Set 11 | lufkin
# Processing Record 1 of Set 12 | naron
# Processing Record 2 of Set 12 | voinesti
# Processing Record 3 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 12 | general roca
# Processing Record 5 of Set 12 | port blair
# Processing Record 6 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 7 of Set 12 | coahuayana
# Processing Record 8 of Set 12 | kamenka
# Processing Record 9 of Set 12 | san clemente
# Processing Record 10 of Set 12 | progreso
# Processing Record 11 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 12 of Set 12 | port hardy
# Processing Record 13 of Set 12 | dubbo
# Processing Record 14 of Set 12 | arivonimamo
# Processing Record 15 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 12 | bad kreuznach
# Processing Record 17 of Set 12 | bajil
# Processing Record 18 of Set 12 | jutai
# Processing Record 19 of Set 12 | tagcatong
# Processing Record 20 of Set 12 | kefalos
# Processing Record 21 of Set 12 | polazna
# Processing Record 22 of Set 12 | mirnyy
# Processing Record 23 of Set 12 | cabedelo
# Processing Record 24 of Set 12 | el alto
# Processing Record 25 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 27 of Set 12 | makhachkala
# Processing Record 28 of Set 12 | sobolevo
# Processing Record 29 of Set 12 | jieshi
# Processing Record 30 of Set 12 | makung
# City not found. Skipping...
# Processing Record 31 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 12 | havoysund
# Processing Record 33 of Set 12 | boyolangu
# Processing Record 34 of Set 12 | jaumave
# Processing Record 35 of Set 12 | niles
# Processing Record 36 of Set 12 | corinto
# Processing Record 37 of Set 12 | saint-augustin
# Processing Record 38 of Set 12 | teruel
# Processing Record 39 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 12 | santa cruz
# Processing Record 41 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 12 | puerto carreno
# Processing Record 43 of Set 12 | usinsk
# Processing Record 44 of Set 12 | zhangzhou
# Processing Record 45 of Set 12 | ternovka
# Processing Record 46 of Set 12 | at-bashi
# Processing Record 47 of Set 12 | tsumeb
# Processing Record 48 of Set 12 | roros
# Processing Record 49 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 12 | ken caryl
# Processing Record 1 of Set 13 | alyangula
# Processing Record 2 of Set 13 | soponya
# Processing Record 3 of Set 13 | baoding
# Processing Record 4 of Set 13 | colesberg
# Processing Record 5 of Set 13 | kiama
# Processing Record 6 of Set 13 | bull savanna
# Processing Record 7 of Set 13 | salalah
# Processing Record 8 of Set 13 | havre
# Processing Record 9 of Set 13 | ilula
# Processing Record 10 of Set 13 | jalu
# Processing Record 11 of Set 13 | seymchan
# Processing Record 12 of Set 13 | mozarlandia
# Processing Record 13 of Set 13 | samarai
# Processing Record 14 of Set 13 | fuyang
# Processing Record 15 of Set 13 | arbuzynka
# Processing Record 16 of Set 13 | batagay
# Processing Record 17 of Set 13 | zhigansk
# Processing Record 18 of Set 13 | vaxjo
# Processing Record 19 of Set 13 | margate
# Processing Record 20 of Set 13 | greve strand
# Processing Record 21 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 13 | armidale
# Processing Record 23 of Set 13 | roald
# Processing Record 24 of Set 13 | tolaga bay
# Processing Record 25 of Set 13 | bonfim
# Processing Record 26 of Set 13 | sakakah
# Processing Record 27 of Set 13 | tabialan
# City not found. Skipping...
# Processing Record 28 of Set 13 | bogale
# Processing Record 29 of Set 13 | rio grande
# Processing Record 30 of Set 13 | tarko-sale
# Processing Record 31 of Set 13 | lahat
# Processing Record 32 of Set 13 | zaozerne
# Processing Record 33 of Set 13 | chernyshevskiy
# Processing Record 34 of Set 13 | la libertad
# Processing Record 35 of Set 13 | ust-kuyga
# Processing Record 36 of Set 13 | elk city
# Processing Record 37 of Set 13 | varkaus
# Processing Record 38 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 13 | inirida
# Processing Record 40 of Set 13 | gat
# Processing Record 41 of Set 13 | cartagena del chaira
# Processing Record 42 of Set 13 | dargaville
# Processing Record 43 of Set 13 | kjopsvik
# Processing Record 44 of Set 13 | sychevka
# Processing Record 45 of Set 13 | mongu
# Processing Record 46 of Set 13 | west helena
# Processing Record 47 of Set 13 | asau
# Processing Record 48 of Set 13 | bogalusa
# Processing Record 49 of Set 13 | viedma
# Processing Record 50 of Set 13 | a coruna
# Processing Record 1 of Set 14 | lockhart
# Processing Record 2 of Set 14 | san rafael
# Processing Record 3 of Set 14 | qostanay
# Processing Record 4 of Set 14 | baherden
# Processing Record 5 of Set 14 | hirara
# Processing Record 6 of Set 14 | camana
# Processing Record 7 of Set 14 | bunia
# Processing Record 8 of Set 14 | chinhoyi
# Processing Record 9 of Set 14 | codrington
# Processing Record 10 of Set 14 | berlevag
# Processing Record 11 of Set 14 | bayanday
# Processing Record 12 of Set 14 | port macquarie
# Processing Record 13 of Set 14 | the pas
# Processing Record 14 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 15 of Set 14 | innisfail
# Processing Record 16 of Set 14 | palmer
# Processing Record 17 of Set 14 | takoradi
# Processing Record 18 of Set 14 | diamantino
# Processing Record 19 of Set 14 | cururupu
# Processing Record 20 of Set 14 | khorixas
# Processing Record 21 of Set 14 | xichang
# Processing Record 22 of Set 14 | yeppoon
# Processing Record 23 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 24 of Set 14 | port-gentil
# Processing Record 25 of Set 14 | harper
# Processing Record 26 of Set 14 | otacilio costa
# Processing Record 27 of Set 14 | zapadnaya dvina
# Processing Record 28 of Set 14 | itaberaba
# Processing Record 29 of Set 14 | vao
# Processing Record 30 of Set 14 | praia
# Processing Record 31 of Set 14 | kargasok
# Processing Record 32 of Set 14 | sao paulo de olivenca
# Processing Record 33 of Set 14 | zelenoborsk
# Processing Record 34 of Set 14 | bonavista
# Processing Record 35 of Set 14 | mackay
# Processing Record 36 of Set 14 | gora kalwaria
# Processing Record 37 of Set 14 | methoni
# Processing Record 38 of Set 14 | kaeo
# Processing Record 39 of Set 14 | jumla
# Processing Record 40 of Set 14 | sioux lookout
# Processing Record 41 of Set 14 | yumen
# Processing Record 42 of Set 14 | kalianget
# Processing Record 43 of Set 14 | warrington
# Processing Record 44 of Set 14 | igarka
# Processing Record 45 of Set 14 | lasa
# Processing Record 46 of Set 14 | saint anthony
# Processing Record 47 of Set 14 | gornopravdinsk
# Processing Record 48 of Set 14 | oktyabrskiy
# Processing Record 49 of Set 14 | guerrero negro
# Processing Record 50 of Set 14 | buin
# Processing Record 1 of Set 15 | ponta delgada
# Processing Record 2 of Set 15 | kjollefjord
# Processing Record 3 of Set 15 | paita
# Processing Record 4 of Set 15 | lumeje
# Processing Record 5 of Set 15 | los llanos de aridane
# Processing Record 6 of Set 15 | auki
# Processing Record 7 of Set 15 | careiro da varzea
# Processing Record 8 of Set 15 | manjacaze
# Processing Record 9 of Set 15 | elban
# Processing Record 10 of Set 15 | lodja
# Processing Record 11 of Set 15 | fukagawa
# Processing Record 12 of Set 15 | klyuchi
# Processing Record 13 of Set 15 | anadyr
# Processing Record 14 of Set 15 | sungairaya
# Processing Record 15 of Set 15 | pemangkat
# Processing Record 16 of Set 15 | payson
# Processing Record 17 of Set 15 | sabzevar
# Processing Record 18 of Set 15 | bud
# Processing Record 19 of Set 15 | morondava
# Processing Record 20 of Set 15 | lamar
# Processing Record 21 of Set 15 | vila
# Processing Record 22 of Set 15 | makakilo city
# Processing Record 23 of Set 15 | baghdad
# Processing Record 24 of Set 15 | belaya gora
# Processing Record 25 of Set 15 | artyom
# Processing Record 26 of Set 15 | jiujiang
# Processing Record 27 of Set 15 | nabire
# Processing Record 28 of Set 15 | tahta
# Processing Record 29 of Set 15 | ondjiva
# Processing Record 30 of Set 15 | ausa
# Processing Record 31 of Set 15 | khandbari
# Processing Record 32 of Set 15 | arbon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     62.60        55           0
# 1  Bambous Virieux      MU -20.3428   57.7575     80.60        74          40
# 2          Fortuna      US  40.5982 -124.1573     52.00        81          20
# 3           Yabrud      SY  33.9674   36.6574     51.80        76           0
# 4           Bethel      US  41.3712  -73.4140     28.00        36           1
# 5            Airai      TL  -8.9266  125.4092     60.39       100         100
# 6            Kapaa      US  22.0752 -159.3190     73.40        64           1
# 7     Punta Arenas      CL -53.1500  -70.9167     69.80        40           0
# 8          Kavieng      PG  -2.5744  150.7967     82.40        79          95
# 9           Faanui      PF -16.4833 -151.7500     81.01        77           0
#
#    Wind Speed Current Description
# 0       16.11           clear sky
# 1        8.05    scattered clouds
# 2        3.78          few clouds
# 3        3.44           clear sky
# 4        3.44           clear sky
# 5        3.02          light rain
# 6       11.50           clear sky
# 7       19.57           clear sky
# 8       10.96     overcast clouds
# 9       13.94           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-85c3a7d8006d> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
